# %%
# %matplotlib inline
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from apscheduler.schedulers.background import BackgroundScheduler
import time
import datetime
from plotcpu import plot_cpu
import csv

# %%
def readCSV(filename, min_line=400, max_line=600):
    data =[]
    counter = 0
    with open(filename) as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            counter += 1
            if counter < min_line:
                continue
            if counter > max_line:
                break
            data.append(float(row[0]))
    return data

# %%
data = []
for i in range(4):
    data.append(readCSV("container" + str(i) + ".csv"))

# %%
plot_cpu(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-12fd481d1c28> in <module>()
# ----> 1 plot_cpu(data)
#
# ~/724/code/deeprl/graphs/plotcpu.py in plot_cpu(data)
#      23     plt.plot(t, data[3]) # cotainer 3
#      24     plt.setp(ax4.get_xticklabels(), visible=True)
# ---> 25     plt.xlabel("Time", font_size=18)
#      26     plt.ylabel("CPU Percentage", font_size=18)
#      27
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in xlabel(s, *args, **kwargs)
#    1510     See there for a full parameter description.
#    1511     """
# -> 1512     return gca().set_xlabel(s, *args, **kwargs)
#    1513
#    1514
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     232         if labelpad is not None:
#     233             self.xaxis.labelpad = labelpad
# --> 234         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     235
#     236     def get_ylabel(self):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1560         if fontdict is not None:
#    1561             self.label.update(fontdict)
# -> 1562         self.label.update(kwargs)
#    1563         self.stale = True
#    1564         return self.label
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     183         sentinel = object()  # bbox can be None, so use another sentinel.
#     184         bbox = kwargs.pop("bbox", sentinel)
# --> 185         super(Text, self).update(kwargs)
#     186         if bbox is not sentinel:
#     187             self.set_bbox(bbox)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property font_size
