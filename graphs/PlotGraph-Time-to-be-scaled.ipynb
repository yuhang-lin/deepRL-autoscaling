# %% [markdown]
# # Plot graphs automatically
# by Yuhang Lin

# %%
# %matplotlib inline
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from apscheduler.schedulers.background import BackgroundScheduler
import time
import datetime
from plotcpu import plot_cpu

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from apis.getcpuinfonoscaling import cpuinfo

# %%
counter = 0
data = []
num_container = 4
for i in range(num_container):
    data.append([])

# %%
def get_data():
    cpu_data = cpuinfo()
    for i in range(num_container):
        data[i].append(cpu_data[i])

# %%
sched = BackgroundScheduler()
# data is retrieved every 1 second
sched.add_job(get_data, 'interval', seconds=1)
sched.start()
print(datetime.datetime.now())
# Out:
# 2019-04-25 12:18:11.850047

# %%
len(data[1])
# Out:
# 0

# %%
def plot_cpu(data):
    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)
    t = np.arange(0.01, len(data[0]), 1)
    
    ax1 = plt.subplot(411)
    plt.plot(t, data[0]) # container 0
    # make these tick labels invisible
    plt.setp(ax1.get_xticklabels(), visible=False)
    
    # share x only
    ax2 = plt.subplot(412, sharex=ax1)
    plt.plot(t, data[1]) # container 1
    plt.setp(ax2.get_xticklabels(), visible=False)
    
    ax3 = plt.subplot(413, sharex=ax1)
    plt.plot(t, data[2]) # cotainer 2
    plt.setp(ax3.get_xticklabels(), visible=False)
    ax4 = plt.subplot(414, sharex=ax1)
    plt.plot(t, data[3]) # cotainer 3
    plt.setp(ax4.get_xticklabels(), visible=True)
  
    plt.show()

# %%
temp = cpuinfo()

# %%
print(datetime.datetime.now())
plot_cpu(data)
# Out:
# 2019-04-25 12:18:19.525514
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:06 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 42, in cpuinfo
#     cpu_percentage=coninfo[dickeys[0]][1]['cpu_inst']['usage']['total']/(10**7)
# KeyError: 'cpu_inst'
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:07 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 367, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/packages/six.py", line 685, in reraise
#     raise value.with_traceback(tb)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 384, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 380, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 266, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 32, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:08 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 42, in cpuinfo
#     cpu_percentage=coninfo[dickeys[0]][1]['cpu_inst']['usage']['total']/(10**7)
# IndexError: list index out of range
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:12 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:13 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:14 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:15 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:16 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:17 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:18 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:19 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:20 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:21 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:22 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:23 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:24 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:25 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:26 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:27 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:28 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:29 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:30 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:31 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:32 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:33 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:34 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:35 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:36 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:37 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:38 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:39 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:40 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:41 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:42 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:43 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:44 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:45 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:46 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:47 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:48 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 34, in cpuinfo
#     coninfo=json.loads(response.content.decode('utf-8'))
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/__init__.py", line 354, in loads
#     return _default_decoder.decode(s)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:49 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fd1e03f6860>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6860>: Failed to establish a new connection: [Errno 113] No route to host',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 32, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6860>: Failed to establish a new connection: [Errno 113] No route to host',))
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:50 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# OSError: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fd1e03f6be0>: Failed to establish a new connection: [Errno 113] No route to host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6be0>: Failed to establish a new connection: [Errno 113] No route to host',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 32, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6be0>: Failed to establish a new connection: [Errno 113] No route to host',))
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:51 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fd1e03f6898>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6898>: Failed to establish a new connection: [Errno 111] Connection refused',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 32, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='152.46.19.80', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fd1e03f6898>: Failed to establish a new connection: [Errno 111] Connection refused',))
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:44:52 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/apis/getcpuinfonoscaling.py", line 42, in cpuinfo
#     cpu_percentage=coninfo[dickeys[0]][1]['cpu_inst']['usage']['total']/(10**7)
# IndexError: list index out of range
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-25 12:49:48 EDT)" skipped: maximum number of running instances reached (1)

# %%
print(datetime.datetime.now())
plot_cpu(data)
# Out:
# 2019-04-25 12:18:12.419447

# %%
# sched.shutdown() # shutdown the scheduler

# %%
# import csv
# for i in range(num_container):
#     with open("container" + str(i) + ".csv", "w") as file:
#         for line in data[i]:
#             file.write(str(line))
#             file.write('\n')
