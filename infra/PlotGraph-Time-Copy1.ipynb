# %% [markdown]
# # Plot graphs automatically
# by Yuhang Lin

# %%
# %matplotlib inline
from __future__ import print_function
from getcpuinfo import cpuinfo
import numpy as np
import matplotlib.pyplot as plt
from apscheduler.schedulers.background import BackgroundScheduler
import time
import datetime
from plotcpu import plot_cpu

# %%
counter = 0
data = []
num_container = 4
for i in range(num_container):
    data.append([])

# %%
def get_data():
    cpu_data = cpuinfo()
    for i in range(num_container):
        data[i].append(cpu_data[i])

# %%
sched = BackgroundScheduler()
# data is retrieved every 1 second
sched.add_job(get_data, 'interval', seconds=1)
sched.start()
print(datetime.datetime.now())
# Out:
# 2019-04-23 19:29:05.539278

# %%
len(data[1])
# Out:
# 2452

# %%
def plot_cpu(data):
    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)
    t = np.arange(0.01, len(data[0]), 1)
    
    ax1 = plt.subplot(411)
    plt.plot(t, data[0]) # container 0
    # make these tick labels invisible
    plt.setp(ax1.get_xticklabels(), visible=False)
    
    # share x only
    ax2 = plt.subplot(412, sharex=ax1)
    plt.plot(t, data[1]) # container 1
    plt.setp(ax2.get_xticklabels(), visible=False)
    
    ax3 = plt.subplot(413, sharex=ax1)
    plt.plot(t, data[2]) # cotainer 2
    plt.setp(ax3.get_xticklabels(), visible=False)
    ax4 = plt.subplot(414, sharex=ax1)
    plt.plot(t, data[3]) # cotainer 3
    plt.setp(ax4.get_xticklabels(), visible=False)
  
    plt.show()

# %%
print(datetime.datetime.now())
plot_cpu(data)
# Out:
# 2019-04-23 20:47:10.191032

# %%
print(datetime.datetime.now())
plot_cpu(data)
# Out:
# 2019-04-23 21:12:50.619551
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:51 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:52 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:53 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:54 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:55 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:56 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:57 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:58 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:12:59 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:00 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:01 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:02 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:03 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:04 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:05 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:06 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:07 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:08 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:09 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:10 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:11 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:12 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:13 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:14 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:15 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:16 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:17 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:18 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:19 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:20 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:21 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:22 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:23 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:24 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:25 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:26 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:27 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:28 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:29 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:30 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:31 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:32 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:33 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:34 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:35 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:36 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:37 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:38 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:39 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:40 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:41 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:42 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:43 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:44 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:45 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:46 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:47 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:48 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:49 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:50 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:51 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:52 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:53 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:54 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:55 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:56 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:57 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:58 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:13:59 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:00 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:01 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:02 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:03 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:04 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:05 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:06 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:07 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:08 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:09 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:10 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:11 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:12 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:13 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:14 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:15 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:16 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:17 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:18 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:19 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:20 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:21 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:22 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:23 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:24 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:25 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:26 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:27 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:28 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:29 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:30 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:31 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:32 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:33 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:34 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:35 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:36 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:37 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:38 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:39 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:40 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:41 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:42 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:43 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:44 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:45 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:46 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:47 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:48 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:49 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:50 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:51 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:52 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:53 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:54 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:55 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:56 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:57 EDT)" skipped: maximum number of running instances reached (1)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:58 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f6b282aba20>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='152.46.16.197', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f6b282aba20>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-3-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/infra/getcpuinfo.py", line 33, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='152.46.16.197', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f6b282aba20>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:14:59 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:00 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:01 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:02 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:03 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:04 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:05 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:06 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:07 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:08 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:09 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:10 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:11 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:12 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:13 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:14 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:15 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:16 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:17 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:18 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:19 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:20 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:21 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:22 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:23 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:24 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:25 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:26 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:27 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:28 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:29 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:30 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:31 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:32 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:33 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:34 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:35 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:36 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:37 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:38 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:39 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:40 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:41 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:42 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:43 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:44 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:45 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:46 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:47 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:48 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:49 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:50 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:51 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:52 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:53 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:54 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:55 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:56 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:57 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:58 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:15:59 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:00 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:01 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:02 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:03 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:04 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:05 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:06 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:07 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:08 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:09 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:10 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:11 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:12 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:13 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:14 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:15 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:16 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:17 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:18 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:19 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:20 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:21 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:22 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:23 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:24 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:25 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:26 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:27 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:28 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:29 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:30 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:31 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:32 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:33 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:34 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:35 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:36 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:37 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:38 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:39 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:40 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:41 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:42 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:43 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:44 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:45 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:46 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:47 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:48 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:49 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:50 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:51 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:52 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:53 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:54 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:55 EDT)" skipped: maximum number of running instances reached (1)
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:56 EDT)" skipped: maximum number of running instances reached (1)

# %%
sched.shutdown() # shutdown the scheduler
# Out:
# Execution of job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:57 EDT)" skipped: maximum number of running instances reached (1)
# Job "get_data (trigger: interval[0:00:01], next run at: 2019-04-23 21:16:58 EDT)" raised an exception
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 171, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 79, in create_connection
#     raise err
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/connection.py", line 69, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 354, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 1026, in _send_output
#     self.send(msg)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/http/client.py", line 964, in send
#     self.connect()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 196, in connect
#     conn = self._new_conn()
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connection.py", line 180, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f6b28d73588>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/connectionpool.py", line 638, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/urllib3/util/retry.py", line 398, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='152.46.16.197', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f6b28d73588>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-3-5c303b930899>", line 2, in get_data
#     cpu_data = cpuinfo()
#   File "/home/ubuntu/724/code/deeprl/infra/getcpuinfo.py", line 33, in cpuinfo
#     response = requests.get(req, headers=headers)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 524, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/sessions.py", line 637, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/requests/adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='152.46.16.197', port=8080): Max retries exceeded with url: /api/v2.0/stats/rubis_rubisclient_1?type=docker&count=2 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f6b28d73588>: Failed to establish a new connection: [Errno 110] Connection timed out',))

# %%
import csv
for i in range(num_container):
    with open("container" + str(i) + ".csv", "w") as file:
        for line in data[i]:
            file.write(str(line))
            file.write('\n')
